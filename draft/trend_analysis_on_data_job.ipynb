# %%
# ===== xxx =====
# ===== reference https://medium.com/@raiyanquaium/how-to-web-scrape-using-beautiful-soup-in-python-without-running-into-http-error-403-554875e5abed =====
import requests
from bs4 import BeautifulSoup
import pandas as pd

# ===== data collection =====
# ===== go to the webpage with keyword=data =====
#url = "https://www.glassdoor.com/Job/jobs.htm?sc.keyword=data"
url = 'https://www.glassdoor.com/Job/data-jobs-SRCH_KO0,4.htm'

# req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
# webpage = urlopen(req).read()

response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).text
job = BeautifulSoup(webpage, 'html.parser')

last_page = job.select_one('[data-test="page-x-of-y"]').text
lp = last_page.split(' ')[-1]

count = 0
for i in range(int(lp)):
    count+=1
    url = 'https://www.glassdoor.com/Job/data-jobs-SRCH_KO0,4_IP'+str(count)+'.htm'
    print(url)
    requests.get(url)




# ===== click the "jobs-location-see-all-link" button =====

# company_name = job.select(".xxx") #1
# job_title = job.select(".xxx") #2
# location = job.select(".xxx") #3
# job_description = job.select(#JobDescriptionContainer)

# ===== check if data-id is new, add to table, else ignore =====
# ===== data-id="1007453014874" =====
# ===== go into details page =====

# ===== table: [Company Name, Job Title, Location, Job Description, Company Size, Company Founded, Company Type, Company Industry, Company Sector, Company Revenue] =====


# ===== reach end of page, jump to next page =====



# ===== data transformation =====
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-1f764127cd57> in <module>()
#      19
#      20 last_page = job.select('.job-search-key-v2y4z')
# ---> 21 [0]['href']
#      22 lp = last_page.split('=')[-1]
#      23
#
# TypeError: list indices must be integers or slices, not str

# %%
url = 'https://www.glassdoor.com/Job/data-jobs-SRCH_KO0,4.htm'

# %%
response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).text
job = BeautifulSoup(response, 'html.parser')

# %%
job
# Out:
# <!DOCTYPE html>
#
# <!DOCTYPE html>
#
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/">
# <head>
# <title>Data Jobs | Glassdoor</title>
# ...

# %%
last_page = job.select_one('[data-test="page-x-of-y"]').text
lp = last_page.split(' ')[-1]

# %%
last_page
# Out:
# 'Page 30 of 30'

# %%
lp
# Out:
# '30'

# %%
count = 0
for i in range(int(lp)):
    count+=1
    url = 'https://www.glassdoor.com/Job/data-jobs-SRCH_KO0,4_IP'+str(count)+'.htm'
    print(url)

# %%
pip install webdriver_manager
# Out:
# ...
#      |████████████████████████████████| 127 kB 40.2 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.7
#     Uninstalling urllib3-1.26.7:
#       Successfully uninstalled urllib3-1.26.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# selenium 4.1.0 requires urllib3[secure]~=1.26, but you have urllib3 1.25.11 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

s = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=s)

driver.get("https://www.glassdoor.com/Job/data-jobs-SRCH_KO0,4.htm")
elem = driver.find_element(By.CSS_SELECTOR, '#FooterPageNav ul li[3]')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# There is no [mac64] chromedriver for browser  in cache
# Trying to download new driver from https://chromedriver.storage.googleapis.com/96.0.4664.45/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/Sllin/.wdm/drivers/chromedriver/mac64/96.0.4664.45]

# %%
# !pip install webdriver_manager
# Out:
# ...
#   Using cached colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# ...

# %%
elem = driver.find_element(By.CSS_SELECTOR, "#FooterPageNav li:last-child > a")

# %%
elem.click(
